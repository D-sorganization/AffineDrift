# %% [markdown]
# # Tutorial: Volume 2 Chapter 4 Orbital Stability and Transversality
#
# Source: `Volume 2 Chapter 4`

# %%
from __future__ import annotations

CHAPTER = 'Volume 2 Chapter 4'
CHAPTER

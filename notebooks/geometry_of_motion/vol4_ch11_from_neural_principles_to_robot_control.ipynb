# %% [markdown]
# # Tutorial: Volume 4 Chapter 11 From Neural Principles to Robot Control
#
# Source: `Volume 4 Chapter 11`

# %%
from __future__ import annotations

CHAPTER = 'Volume 4 Chapter 11'
CHAPTER
